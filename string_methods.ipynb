# %% [markdown]
# # python_string.capitalize

# %%
string = "pyhton is best subject after java"
string.capitalize()
# Out:
# 'Pyhton is best subject after java'

# %%
print(string.casefold())
# Out:
# pyhton is best subject after java

# %%
print(string.center(50, "*"))
# Out:
# ********pyhton is best subject after java*********

# %%
print(string.encode())
# Out:
# b'pyhton is best subject after java'

# %%
string_methods= "python is the best class after java python"
print(string_methods.count("python"))
# Out:
# 2

# %%
print(string_methods.endswith("python"))
# Out:
# True

# %%
string_methods = "python\tis\tbest\tclass"
print(string_methods.expandtabs(9))
# Out:
# python   is       best     class

# %%
school= "rahul goto school today"
print(school.find("z"))
# Out:
# -1

# %%
name= "rakesh"
age = 19

print("my name is {} and i am {} year old".format(name,age))
# Out:
# my name is rakesh and i am 19 year old

# %%
subjects ={"maths":30, "english": 40}
marks = "marks in maths {maths} but in english {english} very low"

print(marks.format_map(subjects))
# Out:
# marks in maths 30 but in english 40 very low

# %%
string = "string has 45 methods"
print(string.index("has"))
# Out:
# 7

# %%
text = "banana"
print(text.index("a", 2))
# Out:
# 3

# %%
cars = "bmw1243"
print(cars.isalnum())
# Out:
# True

# %%
bikes = "bmq 1234"
print(bikes.isalnum())
# Out:
# False

# %%
cloths = "shirt"
print(cloths.isalpha())
# Out:
# True

# %%
clothing= "pants123"
print(clothing.isalpha())
# Out:
# False

# %%
computers= "keyboards"
print(computers.isascii())
# Out:
# True

# %%
coding = "python"
print(coding.isdecimal())
# Out:
# False

# %%
numbers = "12345"
print (numbers.isdecimal())
# Out:
# True

# %%
application = "chrome"
print(application.isdigit())
# Out:
# False

# %%
number = ("1"+"3")
print(number.isdigit())
# Out:
# True

# %%
students = ("rakesh")
print(students.isidentifier())
# Out:
# True

# %%
name = "my var"
print(name.isidentifier())
# Out:
# False

# %%
digits = "13abc"
print(digits.isidentifier())
# Out:
# False

# %%
cold_drinks = "a"
print (cold_drinks.islower())
# Out:
# True

# %%
tools = "hammer"
print(cold_drinks.isnumeric())
# Out:
# False

# %%
num4 = "Ⅻ"
print(num4.isnumeric())  

num5 = "123abc"
print(num5.isnumeric())
# Out:
# True
# False

# %%
number7 = "sports"
print(number7.isprintable())
# Out:
# True

# %%
number8 = " "
print(number8.isspace())
number9 = "akash "
print(number9.isspace())
# Out:
# True
# False

# %%
number10 = "Complex"
print(number10.istitle())
number11 = "trixnity"
print(number11.istitle())
# Out:
# True
# False

# %%
number12 = "STRIN"
print(number12.isupper())
number13 = "computer"
print(number13.isupper())
# Out:
# True
# False

# %%
letters = ["a", "b", "c"]
print("".join(letters))  
marks_student = ["rakesh","suresh","mukesh"]
print("".join(marks_student))
# Out:
# abc
# rakeshsureshmukesh

# %%
number14 = "dell"
print(number14.ljust(12,"*"))
# Out:
# dell********

# %%
number15= "SAKET"
print(number15.lower())
number16 = "PYTHON IS THE BEST CLASS"
print(number16.lower())
# Out:
# saket
# python is the best class

# %%
number17 = "java is the best class"
print (number17.lstrip("java"))
# Out:
#  is the best class

# %%
number18 = "java isa best class after python"
text= str.maketrans("java","csse")
print(number18.translate(text))
# Out:
# cese ise best cless efter python

# %%
text1 = "PythonProgramming"
print(text1.removeprefix("Python"))  

text3 = "2026-Python"
print(text3.removeprefix("2026-"))
# Out:
# Programming
# HelloWorld
# Python

# %%
number19 = "javaprogramming"
print(number19.removesuffix("programming"))
# Out:
# java

# %%
number20 = "hello.py"
print(number20.replace(".py",".python"))
# Out:
# hello.python

# %%
number21 = "alphabets"
print(number21.rfind("h"))
# Out:
# 3

# %%
number22 = "read_books"
print(number22.rindex("k"))
# Out:
# 8

# %%
number23 = "intrument"
print(number23.rjust(22,"*"))
# Out:
# *************intrument

# %%
number24 = "apple-banana-mango"
print(number24.rpartition("-"))
# Out:
# ('apple-banana', '-', 'mango')

# %%
number25 = "maths_english_science"
print(number25.rsplit("_",1))
# Out:
# ['maths_english', 'science']

# %%
number26 = "maths is very easy"

print(number26.split())
# Out:
# ['maths', 'is', 'very', 'easy']

# %%
number27 = "pyhton\nis\nvery\neasy"
print(number27.splitlines())
print(type('number27'))
# Out:
# ['pyhton', 'is', 'very', 'easy']
# <class 'str'>

# %%
number28 = "rakesh.py"
print(number28.startswith("rakesh"))
print(number28.startswith("suresh"))
# Out:
# True
# False

# %%
number29 = "****************python.py******************************************"
print(number29.strip("*"))
# Out:
# python.py

# %%
number30 = 'hello.akash'
print(number30.swapcase())
# Out:
# HELLO.AKASH

# %%
number31 = "java is the easy language"
print(number31.title())
# Out:
# Java Is The Easy Language

# %%
number31 = "css is the best language after python"
list1 = str.maketrans("css","jav")
print(number31.translate(list1))
# Out:
# jvv iv the bevt language after python

# %%
number32 = "hello.ramesh"
print(number32.upper())
# Out:
# HELLO.RAMESH

# %%
number33 = "mango"
print(number33.zfill)
